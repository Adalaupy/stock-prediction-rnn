# %% [markdown]
# # Input Parameter

# %%
Code = 'VOO'
num_days = 30
back_days = 50

# %% [markdown]
# # Call Libraries

# %%
# %run Common.ipynb

# %% [markdown]
# # Predict By RNN model

# %%
rnn_models, scaler = Get_RNN_Mode(Code)

# %%
# %run RNN_Predict.ipynb

# %%
for item in rnn_models:

    model = item[0]

    p = model.input_shape[1]

    predict_result = main_rnn_predict(Code, num_days , back_days, model, p , scaler)
